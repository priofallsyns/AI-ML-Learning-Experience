# %% [markdown]
# <a href="https://colab.research.google.com/github/priofallsyns/AI-ML-Learning-Experience/blob/main/RandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("500hits.csv", encoding="latin-1")

# %%
df=df.drop(columns=["PLAYER", "CS"])

# %%
X=df.iloc[:, 0:13]

# %%
y=df.iloc[:, 13]

# %%
X
# Out:
#      YRS     G     AB     R     H   2B   3B   HR   RBI    BB    SO   SB     BA
# 0     24  3035  11434  2246  4189  724  295  117   726  1249   357  892  0.366
# 1     22  3026  10972  1949  3630  725  177  475  1951  1599   696   78  0.331
# 2     22  2789  10195  1882  3514  792  222  117   724  1381   220  432  0.345
# 3     20  2747  11195  1923  3465  544   66  260  1311  1082  1840  358  0.310
# 4     21  2792  10430  1736  3430  640  252  101     0   963   327  722  0.329
# ..   ...   ...    ...   ...   ...  ...  ...  ...   ...   ...   ...  ...    ...
# 460   15  1920   6653  1105  1665  285   39  291   964  1224  1427  225  0.250
# 461   17  1829   6092   900  1664  379   10  275  1065   936  1453   20  0.273
# 462   15  1834   6499  1062  1661  338   67  210   761   960  1190  315  0.256
# 463   16  1822   6309   714  1660  254   25   54   593   396   489   74  0.263
# 464   15  1468   5629   785  1660  247   71   61   499   266   471  267  0.295
#
# [465 rows x 13 columns]

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y , random_state=42, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score(X_test, y_test)
# Out:
# 0.9032258064516129

# %%
features=pd.DataFrame(rf.feature_importances_, index=X.columns, columns=['Importance'])

# %%
features
# Out:
#      Importance
# YRS    0.032078
# G      0.055918
# AB     0.063787
# R      0.146516
# H      0.120671
# 2B     0.074009
# 3B     0.050019
# HR     0.057969
# RBI    0.089108
# BB     0.047985
# SO     0.059675
# SB     0.060668
# BA     0.141595

# %%
#### We are gonna add parameters now

# %%
rf2=RandomForestClassifier(
    n_estimators=1000,
    criterion='entropy',
    max_depth=14,
    min_samples_split=2,
    random_state=42
)

# %%
rf2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=14, n_estimators=1000,
#                        random_state=42)

# %%
rf2.score(X_test, y_test)
# Out:
# 0.8817204301075269
